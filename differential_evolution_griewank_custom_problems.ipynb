# %% [markdown]
# ## Griewank problem with 100 variables

# %%
import numpy as np
from thefittest.optimizers import DifferentialEvolution
from thefittest.benchmarks import Griewank
from thefittest.tools import donothing
import matplotlib.pyplot as plt


n_dimension = 100
left_border = -100.
right_border = 100.


number_of_iterations = 500
population_size = 500


left_border_array = np.full(
    shape=n_dimension, fill_value=left_border, dtype=np.float64)
right_border_array = np.full(
    shape=n_dimension, fill_value=right_border, dtype=np.float64)

optimizer = DifferentialEvolution(fitness_function=Griewank(),
                              genotype_to_phenotype=donothing,
                              iters=number_of_iterations,
                              pop_size=population_size,
                              left=left_border_array,
                              right=right_border_array,
                              show_progress_each=10,
                              minimization=True,
                              mutation="rand_1",
                              F=0.1,
                              CR=0.5,
                              keep_history=True)

optimizer.fit()

fittest = optimizer.get_fittest()
stats = optimizer.get_stats()

print('The fittest individ:', fittest['phenotype'])
print('with fitness', fittest['fitness'])

fig, ax = plt.subplots(figsize=(14, 7), ncols=1, nrows=1)
ax.plot(range(number_of_iterations), stats['fitness_max'], label = "fitness_max")
ax.set_title('Fitness')
ax.set_ylabel('Fitness value')
ax.set_xlabel("Iterations")
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# 0 iteration with fitness = 57.84314071186906
# 10 iteration with fitness = 46.46674760211958
# 20 iteration with fitness = 27.876996706299202
# 30 iteration with fitness = 20.79766810683479
# 40 iteration with fitness = 12.56531001609347
# 50 iteration with fitness = 7.226652531448036
# 60 iteration with fitness = 5.736848882488687
# 70 iteration with fitness = 3.6039752036330728
# 80 iteration with fitness = 2.8712715813475325
# 90 iteration with fitness = 2.139355554249388
# 100 iteration with fitness = 1.6950471825695308
# 110 iteration with fitness = 1.4521737929250103
# 120 iteration with fitness = 1.2729320381929878
# 130 iteration with fitness = 1.1839361788850982
# 140 iteration with fitness = 1.1262264831378666
# 150 iteration with fitness = 1.0722511611344223
# 160 iteration with fitness = 1.0271486244787467
# 170 iteration with fitness = 0.8928462122245673
# 180 iteration with fitness = 0.71961880925973
# 190 iteration with fitness = 0.5344343669549138
# 200 iteration with fitness = 0.3614585129354486
# 210 iteration with fitness = 0.23857036779630825
# 220 iteration with fitness = 0.1552893562319435
# 230 iteration with fitness = 0.09211030425774203
# 240 iteration with fitness = 0.06501182832453811
# 250 iteration with fitness = 0.03499183253855498
# 260 iteration with fitness = 0.026439883416301213
# 270 iteration with fitness = 0.01736755609994689
# 280 iteration with fitness = 0.010322572445695899
# 290 iteration with fitness = 0.006354715818286172
# 300 iteration with fitness = 0.0043756654568358755
# 310 iteration with fitness = 0.002631253932255051
# 320 iteration with fitness = 0.0016913392112232195
# 330 iteration with fitness = 0.0010117934888904667
# 340 iteration with fitness = 0.0006594704157600884
# 350 iteration with fitness = 0.00040382002700123376
# 360 iteration with fitness = 0.00022796437839622818
# 370 iteration with fitness = 0.00016320134233083206
# 380 iteration with fitness = 9.43147021865709e-05
# 390 iteration with fitness = 5.9619805130362025e-05
# 400 iteration with fitness = 3.831144354227156e-05
# 410 iteration with fitness = 2.4493166047467874e-05
# 420 iteration with fitness = 1.4106988130979659e-05
# 430 iteration with fitness = 8.074811929104087e-06
# 440 iteration with fitness = 5.344092354198082e-06
# 450 iteration with fitness = 3.773594010159087e-06
# 460 iteration with fitness = 2.397485269756139e-06
# 470 iteration with fitness = 1.3768415260129174e-06
# 480 iteration with fitness = 9.429603016197774e-07
# 490 iteration with fitness = 5.422832667356658e-07
# The fittest individ: [ 2.93069743e-05 -6.05686283e-05  5.27875453e-05  3.20149797e-04
#   4.12371756e-05  1.85376553e-05 -5.38219281e-05 -1.30622700e-04
#  -1.26912510e-05  7.37448274e-05 -1.97531213e-04  7.49144590e-04
#   1.85992492e-04  3.33518092e-06  4.68190586e-04  5.12685833e-05
#   1.54172006e-04 -4.16192932e-04  1.09960585e-04  5.41692429e-04
#   2.46596685e-04  1.12548102e-03  2.54681994e-04  2.24249332e-04
#  -8.17220137e-05  1.21550975e-04 -4.06563973e-04 -4.21146211e-04
#  -3.48815011e-04  3.25829773e-04  2.45591174e-04 -3.67749104e-06
#   1.07456778e-04  8.27961948e-04  4.97536625e-04  1.15795379e-04
#   3.04597510e-04 -1.57315045e-04  3.93115393e-04  3.13626628e-04
#  -6.49136441e-05  8.25722816e-04 -2.46614961e-04 -5.14459310e-04
#   1.82482992e-04  6.02119964e-04 -6.21151331e-04 -4.61227000e-06
#  -7.78848761e-04 -1.16063289e-04  3.71666958e-04  8.54447046e-04
#  -5.01419869e-04  9.22632570e-06 -7.34677640e-04 -2.41172659e-04
#  -1.57228943e-04  7.76735424e-04  6.45815051e-04  2.30502471e-03
#   7.19470445e-04 -5.27395004e-04  6.77222089e-04  5.60386460e-04
#   4.10966156e-04  1.07373390e-04 -8.74975340e-04  9.13684823e-04
#   1.20445904e-03 -5.43520578e-04  1.91359522e-04 -5.22064014e-04
#   7.32455732e-04 -2.97736920e-04  8.37680561e-04  5.33463862e-04
#  -1.00566393e-03 -6.71420595e-04  5.90242699e-05 -3.19421063e-04
#   1.51665263e-04  6.37316526e-05 -2.67323491e-04 -1.08925885e-03
#   1.84109697e-04  1.23471421e-03 -3.94778210e-04  4.65986208e-04
#  -1.69919781e-03 -1.15433714e-04 -8.78231650e-04 -6.18573112e-04
#  -1.53307079e-03  7.98894134e-05  3.78477900e-05  1.59752943e-03
#   4.89750306e-04 -3.92498093e-04  5.72821427e-04 -1.40827950e-04]
# with fitness -3.6436499806224987e-07

# %% [markdown]
# ## Custom problem

# %%
import numpy as np
from thefittest.optimizers import DifferentialEvolution
from thefittest.tools import donothing


def custom_problem(x):
    return (5 - x[:, 0])**2 + (12 - x[:, 1])**2


n_dimension = 2
left_border = -100.
right_border = 100.


number_of_iterations = 100
population_size = 100


left_border_array = np.full(
    shape=n_dimension, fill_value=left_border, dtype=np.float64)
right_border_array = np.full(
    shape=n_dimension, fill_value=right_border, dtype=np.float64)

optimizer = DifferentialEvolution(fitness_function=custom_problem,
                              genotype_to_phenotype=donothing,
                              iters=number_of_iterations,
                              pop_size=population_size,
                              left=left_border_array,
                              right=right_border_array,
                              show_progress_each=10,
                              minimization=True,
                              mutation='rand_1',
                              F=0.1,
                              CR=0.5)

optimizer.fit()

fittest = optimizer.get_fittest()
stats = optimizer.get_stats()

print('The fittest individ:', fittest['phenotype'])
print('with fitness', fittest['fitness'])
# Out:
# 0 iteration with fitness = 405.18905039946617
# 10 iteration with fitness = 1.087779830720804
# 20 iteration with fitness = 3.167789173206238e-05
# 30 iteration with fitness = 1.3760294782083427e-08
# 40 iteration with fitness = 1.0799709037977144e-10
# 50 iteration with fitness = 6.844586334833007e-14
# 60 iteration with fitness = 2.284085059358584e-16
# 70 iteration with fitness = 2.2887459987851864e-19
# 80 iteration with fitness = 6.140417003390821e-23
# 90 iteration with fitness = 8.892040123651245e-27
# The fittest individ: [ 5. 12.]
# with fitness -1.0255191767873153e-29
