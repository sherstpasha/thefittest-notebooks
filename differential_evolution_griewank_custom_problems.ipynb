# %% [markdown]
# ## Griewank problem with 100 variables

# %%
import numpy as np
from thefittest.optimizers import DifferentialEvolution
from thefittest.benchmarks import Griewank
from thefittest.tools import donothing
import matplotlib.pyplot as plt


n_dimension = 100
left_border = -100.
right_border = 100.


number_of_iterations = 500
population_size = 500


left_border_array = np.full(
    shape=n_dimension, fill_value=left_border, dtype=np.float64)
right_border_array = np.full(
    shape=n_dimension, fill_value=right_border, dtype=np.float64)

optimizer = DifferentialEvolution(fitness_function=Griewank(),
                              genotype_to_phenotype=donothing,
                              iters=number_of_iterations,
                              pop_size=population_size,
                              left=left_border_array,
                              right=right_border_array,
                              show_progress_each=10,
                              minimization=True,
                              mutation="rand_1",
                              F=0.1,
                              CR=0.5,
                              keep_history=True)

optimizer.fit()

fittest = optimizer.get_fittest()
stats = optimizer.get_stats()

print('The fittest individ:', fittest['phenotype'])
print('with fitness', fittest['fitness'])

fig, ax = plt.subplots(figsize=(14, 7), ncols=1, nrows=1)
ax.plot(range(number_of_iterations), stats['fitness_max'], label = "fitness_max")
ax.set_title('Fitness')
ax.set_ylabel('Fitness value')
ax.set_xlabel("Iterations")
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# 0 iteration with fitness = 61.71603975970772
# 10 iteration with fitness = 42.42975900475185
# 20 iteration with fitness = 30.907778381276664
# 30 iteration with fitness = 18.574922568210773
# 40 iteration with fitness = 11.66926417246884
# 50 iteration with fitness = 8.415718369909353
# 60 iteration with fitness = 5.323689531549968
# 70 iteration with fitness = 3.919596695671686
# 80 iteration with fitness = 2.813767280420035
# 90 iteration with fitness = 2.158953070266528
# 100 iteration with fitness = 1.728302104816363
# 110 iteration with fitness = 1.4647567011503233
# 120 iteration with fitness = 1.3030852711425167
# 130 iteration with fitness = 1.1719617940800084
# 140 iteration with fitness = 1.1184357589202045
# 150 iteration with fitness = 1.0748960455598824
# 160 iteration with fitness = 1.0368623546477798
# 170 iteration with fitness = 0.8937616609726073
# 180 iteration with fitness = 0.7045191521829062
# 190 iteration with fitness = 0.5879240403730408
# 200 iteration with fitness = 0.42869945673441956
# 210 iteration with fitness = 0.2869282984540935
# 220 iteration with fitness = 0.17610911533090257
# 230 iteration with fitness = 0.11994790987187876
# 240 iteration with fitness = 0.0685239852642574
# 250 iteration with fitness = 0.050187486692238936
# 260 iteration with fitness = 0.028693234511130927
# 270 iteration with fitness = 0.019842699551404497
# 280 iteration with fitness = 0.012398441334595778
# 290 iteration with fitness = 0.007503404607373199
# 300 iteration with fitness = 0.005201081506357785
# 310 iteration with fitness = 0.0033261357196855412
# 320 iteration with fitness = 0.002083315498416005
# 330 iteration with fitness = 0.0013779685813144482
# 340 iteration with fitness = 0.000834318771760767
# 350 iteration with fitness = 0.0005033894292924002
# 360 iteration with fitness = 0.0003653978500217647
# 370 iteration with fitness = 0.00021057377838940017
# 380 iteration with fitness = 0.00012755550035237206
# 390 iteration with fitness = 7.575097449907808e-05
# 400 iteration with fitness = 4.7530448095689515e-05
# 410 iteration with fitness = 3.43111160882037e-05
# 420 iteration with fitness = 1.9859550116962943e-05
# 430 iteration with fitness = 1.185823011662368e-05
# 440 iteration with fitness = 8.3702897850646e-06
# 450 iteration with fitness = 4.669467571050134e-06
# 460 iteration with fitness = 3.2010969975848624e-06
# 470 iteration with fitness = 1.991892147112928e-06
# 480 iteration with fitness = 1.1330552455168785e-06
# 490 iteration with fitness = 8.065170635784824e-07
# The fittest individ: [ 3.63426763e-05  1.06851056e-04 -2.17817368e-05  2.01180140e-04
#   6.08487335e-04 -3.01920948e-04 -1.28386196e-04  1.26116837e-04
#  -9.30785523e-05 -1.44734068e-04 -3.37801266e-04 -1.61249058e-04
#  -7.06088757e-05  2.28308575e-04 -4.44075041e-04  2.45785579e-04
#  -6.74588214e-04  5.67084855e-04 -1.91328022e-05 -1.97177197e-04
#   4.03378958e-04  1.63825855e-04 -8.88113836e-05 -4.74213296e-04
#  -9.46399302e-04  8.98562369e-05  2.48464767e-05 -1.41547694e-04
#   2.51776213e-04  6.43771202e-04 -3.27094542e-04  4.82149896e-04
#  -1.83170501e-04  4.47283689e-04  3.64148188e-04  5.32382097e-04
#   3.99001698e-04 -2.73469804e-04 -7.97589254e-04 -7.20457381e-04
#  -2.86426734e-04 -2.40257654e-04 -8.15790826e-04  1.31240721e-03
#  -8.42119595e-04 -1.00045240e-03  6.60936748e-04  5.63138915e-04
#   1.08812244e-03 -3.40690544e-04  7.03055200e-04  6.93216799e-04
#   5.43629871e-04  9.93620859e-04  3.04227130e-04  5.78557024e-04
#   5.17933360e-04 -4.80323421e-04  5.59665094e-04  9.91608727e-04
#  -8.97974956e-04  8.29736737e-04  8.89968128e-04 -4.07370595e-04
#   1.52179183e-04  5.13089424e-04  8.65870205e-04  5.20658309e-04
#  -9.56998057e-04  9.19284209e-04  2.32261293e-04 -1.99617578e-04
#  -3.84754406e-04 -9.40487502e-04  4.33168570e-04  9.59496052e-04
#  -6.36963815e-05 -1.92935104e-03  8.47523762e-04 -6.11027327e-04
#   8.92258414e-04 -3.83700995e-04  6.81894220e-04 -9.51870348e-05
#  -6.01798702e-04 -8.39046095e-04 -7.58036397e-04  1.90653281e-03
#   6.42569740e-04 -1.94363557e-03  4.35804767e-04 -3.85880701e-04
#  -9.59717375e-04  7.93481936e-04  6.23040815e-04  2.83088395e-04
#  -2.77304717e-04  1.64739820e-03  6.65739191e-04 -5.91439147e-04]
# with fitness -4.670766994285813e-07

# %% [markdown]
# ## Custom problem

# %%
import numpy as np
from thefittest.optimizers import DifferentialEvolution
from thefittest.tools import donothing


def custom_problem(x):
    return (5 - x[:, 0])**2 + (12 - x[:, 1])**2


n_dimension = 2
left_border = -100.
right_border = 100.


number_of_iterations = 100
population_size = 100


left_border_array = np.full(
    shape=n_dimension, fill_value=left_border, dtype=np.float64)
right_border_array = np.full(
    shape=n_dimension, fill_value=right_border, dtype=np.float64)

optimizer = DifferentialEvolution(fitness_function=custom_problem,
                              genotype_to_phenotype=donothing,
                              iters=number_of_iterations,
                              pop_size=population_size,
                              left=left_border_array,
                              right=right_border_array,
                              show_progress_each=10,
                              minimization=True,
                              mutation='rand_1',
                              F=0.1,
                              CR=0.5)

optimizer.fit()

fittest = optimizer.get_fittest()
stats = optimizer.get_stats()

print('The fittest individ:', fittest['phenotype'])
print('with fitness', fittest['fitness'])
# Out:
# 0 iteration with fitness = 339.6952564074995
# 10 iteration with fitness = 0.09304597524784286
# 20 iteration with fitness = 7.56604720306675e-05
# 30 iteration with fitness = 3.797207832524025e-08
# 40 iteration with fitness = 1.9329042849157736e-10
# 50 iteration with fitness = 1.4023069992293281e-15
# 60 iteration with fitness = 1.3095583930509008e-16
# 70 iteration with fitness = 7.4732995845183e-21
# 80 iteration with fitness = 1.1136167093249827e-22
# 90 iteration with fitness = 1.3521864776393363e-26
# The fittest individ: [ 5. 12.]
# with fitness -3.155443620884047e-29

# %% [markdown]
# ## jDE

# %%
import numpy as np
from thefittest.optimizers import jDE
from thefittest.benchmarks import Ackley
from thefittest.tools import donothing
import matplotlib.pyplot as plt


n_dimension = 100
left_border = -100.
right_border = 100.


number_of_iterations = 500
population_size = 500


left_border_array = np.full(
    shape=n_dimension, fill_value=left_border, dtype=np.float64)
right_border_array = np.full(
    shape=n_dimension, fill_value=right_border, dtype=np.float64)

optimizer = jDE(fitness_function=Ackley(),
                              genotype_to_phenotype=donothing,
                              iters=number_of_iterations,
                              pop_size=population_size,
                              left=left_border_array,
                              right=right_border_array,
                              show_progress_each=10,
                              minimization=True,
                              mutation="rand_1",
                              keep_history=True)

optimizer.fit()

fittest = optimizer.get_fittest()
stats = optimizer.get_stats()

print('The fittest individ:', fittest['phenotype'])
print('with fitness', fittest['fitness'])

fig, ax = plt.subplots(figsize=(14, 7), ncols=1, nrows=3)

ax[0].plot(range(number_of_iterations), stats['fitness_max'])
ax[0].set_title('Fitness')
ax[0].set_ylabel('Fitness value')
ax[0].set_xlabel("Iterations")

ax[1].plot(range(number_of_iterations), np.array(stats['F']).mean(axis = 1))
ax[1].set_title('Mean F')
ax[1].set_ylabel('Mean F')
ax[1].set_xlabel("Iterations")

ax[2].plot(range(number_of_iterations), np.array(stats['CR']).mean(axis = 1))
ax[2].set_title('Mean CR')
ax[2].set_ylabel('Mean CR')
ax[2].set_xlabel("Iterations")

plt.tight_layout()
plt.show()
# Out:
# 0 iteration with fitness = 21.43983563889652
# 10 iteration with fitness = 20.799236566568858
# 20 iteration with fitness = 20.675129600571736
# 30 iteration with fitness = 20.63738940743697
# 40 iteration with fitness = 20.620782756112792
# 50 iteration with fitness = 20.539102837412802
# 60 iteration with fitness = 20.43307513820001
# 70 iteration with fitness = 20.425284393118957
# 80 iteration with fitness = 20.300003879027134
# 90 iteration with fitness = 20.300003879027134
# 100 iteration with fitness = 20.300003879027134
# 110 iteration with fitness = 20.288723738781847
# 120 iteration with fitness = 20.2574223963384
# 130 iteration with fitness = 20.248311362448003
# 140 iteration with fitness = 20.218787194689146
# 150 iteration with fitness = 20.179401490305906
# 160 iteration with fitness = 20.175626571432783
# 170 iteration with fitness = 20.15435987277488
# 180 iteration with fitness = 20.15435987277488
# 190 iteration with fitness = 20.11671836267944
# 200 iteration with fitness = 20.11671836267944
# 210 iteration with fitness = 20.099733372266815
# 220 iteration with fitness = 20.089300817499787
# 230 iteration with fitness = 20.089300804136464
# 240 iteration with fitness = 20.059302250402467
# 250 iteration with fitness = 20.055437009860125
# 260 iteration with fitness = 20.038835102068298
# 270 iteration with fitness = 20.038835102068298
# 280 iteration with fitness = 20.038835102068298
# 290 iteration with fitness = 20.025197837763702
# 300 iteration with fitness = 20.018869106707132
# 310 iteration with fitness = 20.01422767273587
# 320 iteration with fitness = 20.00820506622748
# 330 iteration with fitness = 20.00820506622748
# 340 iteration with fitness = 20.00820506622748
# 350 iteration with fitness = 20.00820506622748
# 360 iteration with fitness = 20.007641094417764
# 370 iteration with fitness = 20.007031820046144
# 380 iteration with fitness = 20.007031820046144
# 390 iteration with fitness = 20.006923331321275
# 400 iteration with fitness = 20.006297965053225
# 410 iteration with fitness = 20.006297965053225
# 420 iteration with fitness = 20.00319323351587
# 430 iteration with fitness = 20.00289432869892
# 440 iteration with fitness = 20.00249673421358
# 450 iteration with fitness = 20.00249673421358
# 460 iteration with fitness = 20.002331932651806
# 470 iteration with fitness = 20.002331932651806
# 480 iteration with fitness = 20.00147845013107
# 490 iteration with fitness = 20.00147845013107
# The fittest individ: [ 100.         -100.          100.         -100.          100.
#   100.         -100.          100.          100.          100.
#   100.         -100.          100.         -100.         -100.
#  -100.         -100.          100.         -100.          100.
#  -100.          100.          100.         -100.         -100.
#  -100.         -100.          100.         -100.         -100.
#   100.          100.          100.          100.          100.
#   100.          100.         -100.          100.         -100.
#   100.          100.           82.01624363 -100.         -100.
#  -100.          100.         -100.          100.         -100.
#  -100.         -100.          100.         -100.         -100.
#   100.          100.         -100.          100.         -100.
#   100.         -100.          100.          100.          100.
#  -100.         -100.          100.          100.         -100.
#   100.          100.          100.          100.          100.
#   100.          100.          100.          100.          100.
#    65.97768638  100.          100.          100.          100.
#   100.          -99.99513197  100.         -100.         -100.
#   100.         -100.          100.          100.          100.
#  -100.          100.          100.          100.          100.        ]
# with fitness -20.000420808519383

# %% [markdown]
# ## SHADE

# %%
import numpy as np
from thefittest.optimizers import SHADE
from thefittest.benchmarks import Rastrigin
from thefittest.tools import donothing
import matplotlib.pyplot as plt


n_dimension = 100
left_border = -100.
right_border = 100.


number_of_iterations = 500
population_size = 500


left_border_array = np.full(
    shape=n_dimension, fill_value=left_border, dtype=np.float64)
right_border_array = np.full(
    shape=n_dimension, fill_value=right_border, dtype=np.float64)

optimizer = SHADE(fitness_function=Rastrigin(),
                              genotype_to_phenotype=donothing,
                              iters=number_of_iterations,
                              pop_size=population_size,
                              left=left_border_array,
                              right=right_border_array,
                              show_progress_each=10,
                              minimization=True,
                              keep_history=True)

optimizer.fit()

fittest = optimizer.get_fittest()
stats = optimizer.get_stats()

print(stats.keys())
print('The fittest individ:', fittest['phenotype'])
print('with fitness', fittest['fitness'])

fig, ax = plt.subplots(figsize=(14, 7), ncols=1, nrows=3)

ax[0].plot(range(number_of_iterations), stats['fitness_max'])
ax[0].set_title('Fitness')
ax[0].set_ylabel('Fitness value')
ax[0].set_xlabel("Iterations")

ax[1].plot(range(number_of_iterations), np.array(stats['H_F']).mean(axis = 1))
ax[1].set_title('Mean history of the F')
ax[1].set_ylabel('Mean F')
ax[1].set_xlabel("Iterations")

ax[2].plot(range(number_of_iterations), np.array(stats['H_CR']).mean(axis = 1))
ax[2].set_title('Mean history of the CR')
ax[2].set_ylabel('Mean CR')
ax[2].set_xlabel("Iterations")

plt.tight_layout()
plt.show()
# Out:
# 0 iteration with fitness = 249667.62812003584
# 10 iteration with fitness = 104074.02708935749
# 20 iteration with fitness = 52812.72980876264
# 30 iteration with fitness = 30892.661657926084
# 40 iteration with fitness = 16284.480895626273
# 50 iteration with fitness = 8503.470387371004
# 60 iteration with fitness = 5728.399294529025
# 70 iteration with fitness = 3226.346360847547
# 80 iteration with fitness = 2297.365280981476
# 90 iteration with fitness = 1632.709916090312
# 100 iteration with fitness = 1287.7292895539356
# 110 iteration with fitness = 1134.4769861222167
# 120 iteration with fitness = 1039.6434834368597
# 130 iteration with fitness = 972.4701622580963
# 140 iteration with fitness = 894.2163060061663
# 150 iteration with fitness = 828.9265188089211
# 160 iteration with fitness = 822.0300198003061
# 170 iteration with fitness = 822.0300198003061
# 180 iteration with fitness = 820.2231790375772
# 190 iteration with fitness = 793.1073816915673
# 200 iteration with fitness = 793.1073816915673
# 210 iteration with fitness = 790.9326803869791
# 220 iteration with fitness = 774.7575339381507
# 230 iteration with fitness = 697.0427551105508
# 240 iteration with fitness = 697.0427551105508
# 250 iteration with fitness = 667.6157239051098
# 260 iteration with fitness = 667.6157239051098
# 270 iteration with fitness = 667.6157239051098
# 280 iteration with fitness = 667.6157239051098
# 290 iteration with fitness = 667.6157239051098
# 300 iteration with fitness = 667.6157239051098
# 310 iteration with fitness = 667.6157239051098
# 320 iteration with fitness = 667.6157239051098
# 330 iteration with fitness = 667.6157239051098
# 340 iteration with fitness = 667.6157239051098
# 350 iteration with fitness = 667.6157239051098
# 360 iteration with fitness = 667.6157239051098
# 370 iteration with fitness = 667.6157239051098
# 380 iteration with fitness = 667.6157239051098
# 390 iteration with fitness = 667.6157239051098
# 400 iteration with fitness = 667.6157239051098
# 410 iteration with fitness = 667.6157239051098
# 420 iteration with fitness = 667.6157239051098
# 430 iteration with fitness = 667.6157239051098
# 440 iteration with fitness = 664.0908409314594
# 450 iteration with fitness = 664.0908409314594
# 460 iteration with fitness = 664.0908409314594
# 470 iteration with fitness = 664.0908409314594
# 480 iteration with fitness = 664.0908409314594
# 490 iteration with fitness = 664.0908409314594
# dict_keys(['population_g', 'fitness_max', 'H_F', 'H_CR'])
# The fittest individ: [ 2.69889923  0.04738477  0.25076611 -0.14047925 -1.08214552 -0.02229588
#   0.76751289 -0.9185053   0.01193586  1.16538115  0.93005652  0.71766901
#   1.00495791  0.91170994  0.44631686 -0.65774301  0.51596722 -0.27403467
#   0.11249953 -0.02173784  0.72535062  0.07331868 -1.0631937  -0.09873245
#   0.85074428  0.43292578  1.1822421  -1.03515056 -0.13251902 -1.14300573
#   0.12397108  0.80702633  1.09536413 -1.46390785  0.07557239  0.03445656
#  -0.46093424  0.1302038  -0.12808948  0.83765361  0.47336178  0.0088639
#   0.10442057  0.90558144 -0.36076743 -1.03897552  0.01300534  0.02306923
#   2.75661517  1.7565554  -1.00655157 -0.90702284  0.97837211 -0.91716557
#  -0.10378381 -1.99375842  1.1356004  -0.09710852  0.38705291  0.02172788
#   0.34705712 -0.97559256  1.24529794  0.11170902 -1.38597121 -0.13308874
#  -1.14955336 -0.97586504 -1.68135061  0.68714805 -0.17051925  0.96911551
#  -0.6557379   0.13336258 -0.05182583  0.28563021 -0.08839544 -0.72640347
#   0.88605378 -1.27380785  2.10057781 -0.97592929 -0.02695767  0.00989359
#   1.87038334  0.11466196 -1.70450028  2.76847847  0.94164258  2.06537397
#   0.04801339  1.16250695  0.52375529 -0.03552717  1.42592339  0.07555353
#   0.1891982  -0.02698397 -0.9983087   0.69005221]
# with fitness -664.0908409314594
