# %% [markdown]
# ## Griewank problem with 100 variables

# %%
import numpy as np
import matplotlib.pyplot as plt

from thefittest.benchmarks import Griewank
from thefittest.optimizers import DifferentialEvolution


n_dimension = 100
left_border = -100.
right_border = 100.
number_of_iterations = 500
population_size = 500


left_border_array = np.full(
    shape=n_dimension, fill_value=left_border, dtype=np.float64)
right_border_array = np.full(
    shape=n_dimension, fill_value=right_border, dtype=np.float64)

optimizer = DifferentialEvolution(fitness_function=Griewank(),
                                  iters=number_of_iterations,
                                  pop_size=population_size,
                                  left=left_border_array,
                                  right=right_border_array,
                                  show_progress_each=10,
                                  minimization=True,
                                  mutation="rand_1",
                                  F=0.1,
                                  CR=0.5,
                                  keep_history=True)

optimizer.fit()

fittest = optimizer.get_fittest()
stats = optimizer.get_stats()

print('The fittest individ:', fittest['phenotype'])
print('with fitness', fittest['fitness'])

fig, ax = plt.subplots(figsize=(14, 7), ncols=1, nrows=1)
ax.plot(range(number_of_iterations), stats['max_fitness'], label = "max_fitness")
ax.set_title('Fitness')
ax.set_ylabel('Fitness value')
ax.set_xlabel("Iterations")
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# 0-th iteration with the best fitness = 62.24259439241526
# 10-th iteration with the best fitness = 47.41113726567118
# 20-th iteration with the best fitness = 30.96291266032922
# 30-th iteration with the best fitness = 17.828125404394306
# 40-th iteration with the best fitness = 12.929938789653534
# 50-th iteration with the best fitness = 8.071173539399219
# 60-th iteration with the best fitness = 5.798353774759349
# 70-th iteration with the best fitness = 3.643775489986891
# 80-th iteration with the best fitness = 2.788090769557081
# 90-th iteration with the best fitness = 2.133458616714754
# 100-th iteration with the best fitness = 1.7359333124164813
# 110-th iteration with the best fitness = 1.4625638484036603
# 120-th iteration with the best fitness = 1.2795542454504316
# 130-th iteration with the best fitness = 1.1880543778335324
# 140-th iteration with the best fitness = 1.1195562752741945
# 150-th iteration with the best fitness = 1.071555341820957
# 160-th iteration with the best fitness = 1.011790479176477
# 170-th iteration with the best fitness = 0.902234970801602
# 180-th iteration with the best fitness = 0.6844143922415186
# 190-th iteration with the best fitness = 0.4873192889819322
# 200-th iteration with the best fitness = 0.399839356143994
# 210-th iteration with the best fitness = 0.2691919020703578
# 220-th iteration with the best fitness = 0.17197265750743695
# 230-th iteration with the best fitness = 0.11147927389535028
# 240-th iteration with the best fitness = 0.07473648028955227
# 250-th iteration with the best fitness = 0.04152579598434303
# 260-th iteration with the best fitness = 0.028533748617145305
# 270-th iteration with the best fitness = 0.01775688123675523
# 280-th iteration with the best fitness = 0.010784491876235647
# 290-th iteration with the best fitness = 0.00678288400391025
# 300-th iteration with the best fitness = 0.004506065522236757
# 310-th iteration with the best fitness = 0.002628141177059007
# 320-th iteration with the best fitness = 0.00169792802547164
# 330-th iteration with the best fitness = 0.001064687216285054
# 340-th iteration with the best fitness = 0.0006721580483386447
# 350-th iteration with the best fitness = 0.00043476461299674085
# 360-th iteration with the best fitness = 0.000259191400022174
# 370-th iteration with the best fitness = 0.00016376522817618255
# 380-th iteration with the best fitness = 0.0001043357949636059
# 390-th iteration with the best fitness = 6.300504172540577e-05
# 400-th iteration with the best fitness = 4.0083850663341636e-05
# 410-th iteration with the best fitness = 2.5521251747817608e-05
# 420-th iteration with the best fitness = 1.5982358794297546e-05
# 430-th iteration with the best fitness = 9.651155857715032e-06
# 440-th iteration with the best fitness = 6.505716749205526e-06
# 450-th iteration with the best fitness = 4.044106461043029e-06
# 460-th iteration with the best fitness = 2.363149126383135e-06
# 470-th iteration with the best fitness = 1.4528620153608784e-06
# 480-th iteration with the best fitness = 9.752425045306268e-07
# 490-th iteration with the best fitness = 6.243355226143166e-07
# The fittest individ: [-1.06355730e-04 -2.08465118e-04  6.08708217e-05  2.00370098e-05
#  -2.12556483e-04 -3.63402226e-04 -1.17055430e-04  3.24318430e-05
#  -5.66872931e-05  4.68282057e-04 -3.06621786e-04 -2.78575587e-04
#   4.38244086e-04 -3.55311751e-04 -3.39160478e-04 -1.29611649e-04
#   3.98320182e-04 -2.23075015e-04 -3.19199576e-04  9.89584507e-04
#   9.65696402e-04 -8.89861646e-06 -3.73651475e-04 -2.51232140e-05
#  -5.14007046e-04  1.93655929e-06  3.03325376e-04  5.31055915e-05
#   4.53064056e-04 -1.27135598e-04 -2.80882167e-04  2.66119622e-04
#   7.70413437e-04 -5.31357034e-05  4.70246384e-05 -2.15029194e-04
#  -2.88857485e-05  5.86139152e-04  4.11963547e-04 -2.08096249e-04
#  -3.61214817e-04 -1.91842985e-04  1.30227605e-03  6.15609487e-05
#  -9.85381336e-05  1.20233027e-04 -5.92505226e-04 -4.73244167e-05
#   9.12596856e-04  9.26159882e-04 -4.66120349e-05 -2.45138760e-04
#   1.51293269e-04  1.23990809e-04  4.09558138e-04  4.21067380e-04
#  -1.12090482e-03 -1.07280145e-03 -2.54941970e-04 -6.06563785e-04
#   1.15087120e-03 -3.29593675e-04  8.93587923e-04 -5.95012008e-04
#   2.54552973e-04 -2.91503942e-04 -2.92885739e-04 -3.35842333e-04
#   1.23012257e-04 -3.34371506e-04  9.02274620e-04 -2.86329584e-04
#  -4.71916570e-04 -3.98237926e-04  5.41573169e-04  2.41222110e-05
#   3.82264237e-04  2.55691702e-04  1.87911425e-03 -2.94827132e-04
#  -6.04835195e-04  2.14373292e-04  4.88692275e-04 -2.27250120e-04
#  -1.03510491e-03 -1.41167061e-03 -3.91737014e-04  1.21792566e-03
#  -1.60000323e-04 -7.95769770e-05 -7.50741102e-04  1.79796090e-03
#  -1.24370498e-04 -2.12122809e-03  9.47044649e-04  3.89069562e-04
#  -8.74093188e-04  1.31204372e-03 -1.56394342e-04  3.28078743e-05]
# with fitness -3.925988536490621e-07

# %% [markdown]
# ## Custom problem

# %%
from thefittest.optimizers import DifferentialEvolution


def custom_problem(x):
    return (5 - x[:, 0])**2 + (12 - x[:, 1])**2


n_dimension = 2
left_border = -100.
right_border = 100.


number_of_iterations = 100
population_size = 100


left_border_array = np.full(
    shape=n_dimension, fill_value=left_border, dtype=np.float64)
right_border_array = np.full(
    shape=n_dimension, fill_value=right_border, dtype=np.float64)

optimizer = DifferentialEvolution(fitness_function=custom_problem,
                                  iters=number_of_iterations,
                                  pop_size=population_size,
                                  left=left_border_array,
                                  right=right_border_array,
                                  show_progress_each=10,
                                  minimization=True,
                                  mutation='rand_1',
                                  F=0.1,
                                  CR=0.5)

optimizer.fit()

fittest = optimizer.get_fittest()

print('The fittest individ:', fittest['phenotype'])
print('with fitness', fittest['fitness'])
# Out:
# 0-th iteration with the best fitness = 713.7803646608645
# 10-th iteration with the best fitness = 0.5294409027789113
# 20-th iteration with the best fitness = 0.0007714046324662251
# 30-th iteration with the best fitness = 1.5525706016085546e-06
# 40-th iteration with the best fitness = 3.225129835219999e-09
# 50-th iteration with the best fitness = 1.3457706276464753e-12
# 60-th iteration with the best fitness = 4.416397846638536e-16
# 70-th iteration with the best fitness = 2.177599052757919e-18
# 80-th iteration with the best fitness = 4.2607661701320284e-21
# 90-th iteration with the best fitness = 7.807656146116338e-24
# The fittest individ: [ 5. 12.]
# with fitness -2.8430547024165265e-26

# %% [markdown]
# ## jDE

# %%
from thefittest.benchmarks import Ackley
from thefittest.optimizers import jDE


optimizer = jDE(fitness_function=Ackley(),
                iters=number_of_iterations,
                pop_size=population_size,
                left=left_border_array,
                right=right_border_array,
                show_progress_each=10,
                minimization=True,
                mutation="rand_1",
                keep_history=True)

optimizer.fit()

fittest = optimizer.get_fittest()
stats = optimizer.get_stats()

print('The fittest individ:', fittest['phenotype'])
print('with fitness', fittest['fitness'])

fig, ax = plt.subplots(figsize=(14, 7), ncols=1, nrows=3)

ax[0].plot(range(number_of_iterations), stats['max_fitness'])
ax[0].set_title('Fitness')
ax[0].set_ylabel('Fitness value')
ax[0].set_xlabel("Iterations")

ax[1].plot(range(number_of_iterations), np.array(stats['F']).mean(axis = 1))
ax[1].set_title('Mean F')
ax[1].set_ylabel('Mean F')
ax[1].set_xlabel("Iterations")

ax[2].plot(range(number_of_iterations), np.array(stats['CR']).mean(axis = 1))
ax[2].set_title('Mean CR')
ax[2].set_ylabel('Mean CR')
ax[2].set_xlabel("Iterations")

plt.tight_layout()
plt.show()
# Out:
# 0-th iteration with the best fitness = 13.356201722910777
# 10-th iteration with the best fitness = 4.440892098500626e-16
# 20-th iteration with the best fitness = 4.440892098500626e-16
# 30-th iteration with the best fitness = 4.440892098500626e-16
# 40-th iteration with the best fitness = 4.440892098500626e-16
# 50-th iteration with the best fitness = 4.440892098500626e-16
# 60-th iteration with the best fitness = 4.440892098500626e-16
# 70-th iteration with the best fitness = 4.440892098500626e-16
# 80-th iteration with the best fitness = 4.440892098500626e-16
# 90-th iteration with the best fitness = 4.440892098500626e-16
# The fittest individ: [0. 0.]
# with fitness -4.440892098500626e-16

# %% [markdown]
# ## SHADE

# %%
from thefittest.benchmarks import Rastrigin
from thefittest.optimizers import SHADE


optimizer = SHADE(fitness_function=Rastrigin(),
                  iters=number_of_iterations,
                  pop_size=population_size,
                  left=left_border_array,
                  right=right_border_array,
                  show_progress_each=10,
                  minimization=True,
                  keep_history=True)

optimizer.fit()

fittest = optimizer.get_fittest()
stats = optimizer.get_stats()

print('The fittest individ:', fittest['phenotype'])
print('with fitness', fittest['fitness'])

fig, ax = plt.subplots(figsize=(14, 7), ncols=1, nrows=3)

ax[0].plot(range(number_of_iterations), stats['max_fitness'])
ax[0].set_title('Fitness')
ax[0].set_ylabel('Fitness value')
ax[0].set_xlabel("Iterations")

ax[1].plot(range(number_of_iterations), np.array(stats['H_F']).mean(axis = 1))
ax[1].set_title('Mean history of the F')
ax[1].set_ylabel('Mean F')
ax[1].set_xlabel("Iterations")

ax[2].plot(range(number_of_iterations), np.array(stats['H_CR']).mean(axis = 1))
ax[2].set_title('Mean history of the CR')
ax[2].set_ylabel('Mean CR')
ax[2].set_xlabel("Iterations")

plt.tight_layout()
plt.show()
# Out:
# 0-th iteration with the best fitness = 26.513199974890494
# 10-th iteration with the best fitness = 7.3823713588232724
# 20-th iteration with the best fitness = 1.053085535235775
# 30-th iteration with the best fitness = 0.19454792675195343
# 40-th iteration with the best fitness = 0.004504434403711954
# 50-th iteration with the best fitness = 0.004504434403711954
# 60-th iteration with the best fitness = 0.0029667343155885817
# 70-th iteration with the best fitness = 8.309754634083788e-05
# 80-th iteration with the best fitness = 8.732131316691039e-06
# 90-th iteration with the best fitness = 1.7576256361451215e-07
# The fittest individ: [ 1.48687651e-06 -3.25024360e-06]
# with fitness -2.5344366605395408e-09
